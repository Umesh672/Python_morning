# %% [markdown]
# **file handling**

# %%
file name              type of file
==============structure/semi-structure==================
text                   .txt or text
word                   .doc or docx
pdf                    .pdf
csv(excel)             .csv(comma separated value)
excel                  .xlsx(tabular)
json                   .json(dict. key-value)

=========================unstructured====================
xml                    .xml(image data)
parquet                .delta/.parquet(DE)
delta                  .delta(DE)
image                  .jpg/.jpeg/.png
video                  .mp4
audio                  .mp3

# %%
**task*
- get the package name to read each file

# %%
pyspark- for big data - it is like python - is language
data bricks to read pyspark code

# %% [markdown]
# **how to read text file**

# %%
- inorder bto read any file, we need 3 points
- where is the file located: directory or folder name
  'C:\Users\ukush\Downloads'
- what is the file name
  'mbox-short'
- what is the extension
  '.txt'

location\filename.typeoffile

# %%
location\filename.typeoffile

# %%
"C:\Users\ukush\Downloads\mbox-short.txt"

# %%
path='C:\Users\ukush\Downloads\mbox-short.txt'

# %%
path="C:\Users\ukush\Downloads\mbox-short.txt"

# %% [markdown]
# ## Task

# %%
path="C:\Users\ukush\Downloads\data files\android-games.csv"

path="C:\Users\ukush\Downloads\data files\bank.csv"

path="C:\Users\ukush\Downloads\data files\california_housing.csv"

path="C:\Users\ukush\Downloads\data files\IMDB Dataset_sample.xlsx"

path="C:\Users\ukush\Downloads\data files\mbox-short.txt"

path="C:\Users\ukush\Downloads\data files\metamorphosis clean.txt"

path="C:\Users\ukush\Downloads\data files\NAMES.csv"

path="C:\Users\ukush\Downloads\data files\Salary_Data.csv"

path="C:\Users\ukush\Downloads\data files\Visadataset.csv"

path="C:\Users\ukush\Downloads\data files\winequality_red.csv"

# %% [markdown]
# **unicode-error**

# %%
- whenever we see apply the single slash python gives the error
- this is called as Unicode error
- Unicode means you need to provide double slash
- we can avoid unicode error by providing a r letter in starting of the path

# %%
"C:\\Users\\ukush\\Downloads\\data files\\winequality_red.csv"
# Out:
# 'C:\\Users\\ukush\\Downloads\\data files\\winequality_red.csv'

# %%
r"C:\Users\ukush\Downloads\data files\winequality_red.csv"
# Out:
# 'C:\\Users\\ukush\\Downloads\\data files\\winequality_red.csv'

# %%
# root folder or root directory is different

# %% [markdown]
# **read the file**
#
# - step-1: take the path
# - step-2: open the file
# - step-3: read the file

# %%
path=r"C:\Users\ukush\Downloads\data files\winequality_red.csv"
open(path)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\ukush\\Downloads\\data files\\winequality_red.csv' mode='r' encoding='cp1252'>

# %%
Character Meaning
--------- ---------------------------------------------------------------
'r'       open for reading (default)
'w'       open for writing, truncating the file first
            we load the data which has already have info.
            that info. is gone, that is called as truncating
'x'       create a new file and open it for writing
            imagine that there is no empty file in your local
            it will create the file and write the info.
'a'       open for writing, appending to the end of the file if it exists
            already info. is there we want to add some data
'b'       binary mode
            binary is a data type: b'abc'
't'       text mode (default)
'+'       open a disk file for updating (reading and writing)

# %%
path=r"C:\Users\ukush\Downloads\data files\winequality_red.csv"
file=open(path)
data=file.read()
print(data)

# this method is applicable only for text file
# we cannot read
# Out:
# fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,quality
#
# 7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5
#
# 7.8,0.88,0,2.6,0.098,25,67,0.9968,3.2,0.68,9.8,5
#
# 7.8,0.76,0.04,2.3,0.092,15,54,0.997,3.26,0.65,9.8,5
#
# 11.2,0.28,0.56,1.9,0.075,17,60,0.998,3.16,0.58,9.8,6
#
# 7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5
#
# 7.4,0.66,0,1.8,0.075,13,40,0.9978,3.51,0.56,9.4,5
#
# 7.9,0.6,0.06,1.6,0.069,15,59,0.9964,3.3,0.46,9.4,5
#
# 7.3,0.65,0,1.2,0.065,15,21,0.9946,3.39,0.47,10,7
#
# 7.8,0.58,0.02,2,0.073,9,18,0.9968,3.36,0.57,9.5,7
#
# 7.5,0.5,0.36,6.1,0.071,17,102,0.9978,3.35,0.8,10.5,5
#
# 6.7,0.58,0.08,1.8,0.097,15,65,0.9959,3.28,0.54,9.2,5
#
# 7.5,0.5,0.36,6.1,0.071,17,102,0.9978,3.35,0.8,10.5,5
#
# 5.6,0.615,0,1.6,0.089,16,59,0.9943,3.58,0.52,9.9,5
#
# 7.8,0.61,0.29,1.6,0.114,9,29,0.9974,3.26,1.56,9.1,5
#
# 8.9,0.62,0.18,3.8,0.176,52,145,0.9986,3.16,0.88,9.2,5
#
# ...

# %% [markdown]
# **filenotfounderror**
# - check the file is available in that location
# - which are passing

# %%
data
# Out:
# 'fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,quality\n\n7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5\n\n7.8,0.88,0,2.6,0.098,25,67,0.9968,3.2,0.68,9.8,5\n\n7.8,0.76,0.04,2.3,0.092,15,54,0.997,3.26,0.65,9.8,5\n\n11.2,0.28,0.56,1.9,0.075,17,60,0.998,3.16,0.58,9.8,6\n\n7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5\n\n7.4,0.66,0,1.8,0.075,13,40,0.9978,3.51,0.56,9.4,5\n\n7.9,0.6,0.06,1.6,0.069,15,59,0.9964,3.3,0.46,9.4,5\n\n7.3,0.65,0,1.2,0.065,15,21,0.9946,3.39,0.47,10,7\n\n7.8,0.58,0.02,2,0.073,9,18,0.9968,3.36,0.57,9.5,7\n\n7.5,0.5,0.36,6.1,0.071,17,102,0.9978,3.35,0.8,10.5,5\n\n6.7,0.58,0.08,1.8,0.097,15,65,0.9959,3.28,0.54,9.2,5\n\n7.5,0.5,0.36,6.1,0.071,17,102,0.9978,3.35,0.8,10.5,5\n\n5.6,0.615,0,1.6,0.089,16,59,0.9943,3.58,0.52,9.9,5\n\n7.8,0.61,0.29,1.6,0.114,9,29,0.9974,3.26,1.56,9.1,5\n\n8.9,0.62,0.18,3.8,0.176,52,145,0.9986,3.16,0.88,9.2,5\n\n8.9,0.62,0.19,3.9,0.17,51,148,0.998
# ...

# %%
r"C:\Users\ukush\Downloads\data files\mbox-short.txt"
# Out:
# 'C:\\Users\\ukush\\Downloads\\data files\\mbox-short.txt'

# %%
path=r"C:\Users\ukush\Downloads\data files\mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
data
# Out:
# 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\nReturn-Path: <postmaster@collab.sakaiproject.org>\nReceived: from murder (mail.umich.edu [141.211.14.90])\n\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nX-Sieve: CMU Sieve 2.3\nReceived: from murder ([unix socket])\n\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nReceived: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n\tSat, 5 Jan 2008 09:14:15 -0500\nReceived: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n\t 5 Jan 2008 09:14:10 -0500\nReceived: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n\tby paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;\n\tSat,  5 Jan 2008 14:10:05 +0000 (GMT)\nMessage-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>\nMime-Version: 1.0\n
# ...

# %%
# r"C:\Users\ukush\Downloads\data files\mbox-short.txt"
# "C:\Users\ukush\Downloads\data files\mbox-short.txt"

# %% [markdown]
# **method 2**
#
# - when in real time diff. laptops diff. root folders
#
# - it is not a good way to rovide full path with root directory
#
# - so that we will keep data file in python location itself
#
# - which means both datafiles and python file in same location
#
# - then no need to provide folder name
#
# - Only file name and extension is enough

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python'

# %%
path=r"mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
data
# Out:
# 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\nReturn-Path: <postmaster@collab.sakaiproject.org>\nReceived: from murder (mail.umich.edu [141.211.14.90])\n\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nX-Sieve: CMU Sieve 2.3\nReceived: from murder ([unix socket])\n\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nReceived: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n\tSat, 5 Jan 2008 09:14:15 -0500\nReceived: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n\t 5 Jan 2008 09:14:10 -0500\nReceived: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n\tby paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;\n\tSat,  5 Jan 2008 14:10:05 +0000 (GMT)\nMessage-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>\nMime-Version: 1.0\n
# ...

# %% [markdown]
# **method 3**
#
# - using with keywords

# %%
- when we use open and read in different lines
- python ondirectly takes the session approach
- the session woll close after some time
- the stored data will not able to use(its gone)
- we need to perform the same operation under session
- by using with keyword

# %%
path=r"mbox-short.txt"
file=open(path)
data=file.read()
print(data)

# %%
with <open command> as <variable name>
    <>

# %%
path=r"mbox-short.txt"
with open(path) as file:
    data=file.read()

# %%
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
**encoding**

- encoding is a method, to hide the characters for security purpose
- when ever we read some file we have some spl characters
- to avoid those we will use encoding argument while open the file path
- we haveso many encoding methods are there
- **utf-8-sig** is one of the main encoding methods

**mode**
- while opening the file there is mode argument
- by default Mode='r' which means read 
- if you want ti write Mode='w'

**file not found error**
- filr not found error means file is not available in the given path
- this is completely our job, this error made by us only
- go to the path, check the file name in that location

**permission error**
- the file we are using in python is already opened in your laptop
- you might be see or might not able to see
- if you see the file opend, then close the file locally the start read
                           - if you dont see the opened file, restart the computer

# %%
path=r"mbox-short.txt"
with open(path,
         mode='r'
         encoding=') as file:
    data=file.read()

# %% [markdown]
# **how to write the file**

# %%
**method 2**
path=r"mbox-short.txt"
file=open(path)
data=file.read()
print(data)

# %%
- write the file also same way like read the file
-**checkpoint no-1**
- what is the file name, which you want to write some thing
- is that file existed in your laptop or not
- generally we will give the new name, that is not existed in your laptop

**checkpoint no-2**
- choose the correct mode
- for writing we have many modes
- mode='w': clear the existed data and overite with new data
- mode='a': dont want clear old data, new data append with old data

**checkpoint no-3**
- for reading we will use read
- for writing we will use write

# %%
path="mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
path="newfile.txt"
file=open(path,'w')
data=file.write('when we use open and read in different lines.')
file2=open(path)
print(file2.read())
# Out:
# when we use open and read in different lines.

# %%
path="newfile1.txt"
file=open(path,mode='w')
data=file.write('when we use open and read in different lines.')
data
# Out:
# 45

# %%
path="newfile3.txt"
with open(path,'w') as file:
    file.write('when we use open and read in different lines.')
    file.write('if you dont folloe')

# %% [markdown]
# **iterating each line using for loop**

# %%
path="mbox-short.txt"
file=open(path)
data=file.read()

for i in data:
    print(i)
# Out:
# F
# r
# o
# m
#
# s
# t
# e
# p
# h
# e
# n
# .
# m
# a
# r
# q
# u
# a
# r
# d
# @
# u
# c
# t
# .
# a
# c
# .
# z
# a
#
# S
# a
# t
#
# J
# a
# n
#
#
# 5
#
# 0
# 9
# :
# 1
# 4
# :
# 1
# 6
#
# 2
# 0
# 0
# 8
#
#
# R
# e
# t
# u
# r
# n
# -
# P
# a
# t
# h
# :
#
# <
# p
# o
# s
# t
# m
# a
# s
# t
# e
# r
# @
# c
# o
# l
# l
# a
# b
# .
# s
# a
# k
# a
# i
# p
# r
# o
# j
# e
# c
# t
# .
# o
# r
# g
# >
#
#
# R
# e
# c
# e
# i
# v
# e
# d
# :
#
# f
# r
# o
# m
#
# m
# u
# r
# d
# e
# r
#
# (
# m
# a
# i
# l
# .
# u
# m
# i
# c
# h
# .
# e
# d
# u
#
# [
# 1
# 4
# 1
# .
# 2
# 1
# 1
# .
# 1
# 4
# .
# 9
# 0
# ]
# )
#
#
#
#
# b
# y
#
# f
# r
# a
# n
# k
# e
# n
# s
# t
# e
# i
# n
# .
# m
# a
# i
# l
# .
# u
# m
# i
# c
# h
# .
# e
# d
# u
#
# (
# C
# y
# r
# u
# s
#
# v
# 2
# .
# 3
# .
# 8
# )
#
# w
# i
# t
# h
#
# L
# M
# T
# P
# A
# ;
#
#
#
#
# S
# a
# t
# ,
#
# 0
# 5
#
# J
# a
# n
#
# 2
# 0
# 0
# 8
#
# 0
# 9
# :
# 1
# 4
# :
# 1
# 6
#
# -
# 0
# 5
# 0
# 0
#
#
# X
# -
# S
# i
# e
# v
# e
# ...

# %%
path="mbox-short.txt"
file=open(path)
data=file.read()

for i in data.split():
    print(i)
# Out:
# From
# stephen.marquard@uct.ac.za
# Sat
# Jan
# 5
# 09:14:16
# 2008
# Return-Path:
# <postmaster@collab.sakaiproject.org>
# Received:
# from
# murder
# (mail.umich.edu
# [141.211.14.90])
# by
# frankenstein.mail.umich.edu
# (Cyrus
# v2.3.8)
# with
# LMTPA;
# Sat,
# 05
# Jan
# 2008
# 09:14:16
# -0500
# X-Sieve:
# CMU
# Sieve
# 2.3
# Received:
# from
# murder
# ([unix
# socket])
# by
# mail.umich.edu
# (Cyrus
# v2.2.12)
# with
# LMTPA;
# Sat,
# 05
# Jan
# 2008
# 09:14:16
# -0500
# Received:
# from
# holes.mr.itd.umich.edu
# (holes.mr.itd.umich.edu
# [141.211.14.79])
# by
# flawless.mail.umich.edu
# ()
# with
# ESMTP
# id
# m05EEFR1013674;
# Sat,
# 5
# Jan
# 2008
# 09:14:15
# -0500
# Received:
# FROM
# paploo.uhi.ac.uk
# (app1.prod.collab.uhi.ac.uk
# [194.35.219.184])
# BY
# holes.mr.itd.umich.edu
# ID
# 477F90B0.2DB2F.12494
# ;
# 5
# Jan
# 2008
# 09:14:10
# -0500
# Received:
# from
# paploo.uhi.ac.uk
# (localhost
# [127.0.0.1])
# by
# paploo.uhi.ac.uk
# (Postfix)
# with
# ESMTP
# id
# ...

# %%
path="mbox-short.txt"
file=open(path)
data=file.read()

for i in data.split('\n'):
    print(i)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
**method 2**

# %%
path="mbox-short.txt"
file=open(path,mode='r',encoding='utf-8-sig')
data=file.read()

for i in data.split('\n'):
    print(i)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
path="mbox-short.txt"
file=open(path,mode='r',encoding='utf-8-sig')

for i in file:
    print(i)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# X-Sieve: CMU Sieve 2.3
#
# Received: from murder ([unix socket])
#
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 	Sat, 5 Jan 2008 09:14:15 -0500
#
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 	 5 Jan 2008 09:14:10 -0500
#
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
path="mbox-short.txt"
file=open(path,mode='r',encoding='utf-8-sig')

for i in file('\n'):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 path="mbox-short.txt"
#       2 file=open(path,mode='r',encoding='utf-8-sig')
# ----> 4 for i in file('/n'):
#       5     print(i)
#
# TypeError: '_io.TextIOWrapper' object is not callable

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python'

# %%
path="newfile.txt"
file=open(path,'w')
data=file.write('when we use open and read in different lines.')
file2=open(path)
print(file2.read())

# %%
path="Umesh Doc.txt"
file=open(path,'w')
data=file.write('In technical terms, comments are lines of code or statement that the interpreter or Python compiler ignores during execution. These are used to write some programmer readable information/explanation about the code, which helps other programmers understand the code. Python offers a pretty simple and straightforward way to write a comment. We can write a single-line comment by adding a single # character before any statement or line of code.') 
file2=open(path)
print(file2.read())
# Out:
# In technical terms, comments are lines of code or statement that the interpreter or Python compiler ignores during execution. These are used to write some programmer readable information/explanation about the code, which helps other programmers understand the code. Python offers a pretty simple and straightforward way to write a comment. We can write a single-line comment by adding a single # character before any statement or line of code.

# %%
# read the file

# %%
# you wnat to save the output in a different folder
# but in same root directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python'

# %%
path=r'C:\Users\ukush\Documents\Naresh IT\Python\output\write_text.txt'
with open(path,mode='w') as file:
    file.write('hello i am umesh')

# %%
- here we created manually the folder name='output'

- this folder in same python root directory

- python root directory is:

    -Naresh IT\Python\

- output root dir. is:

    -Naresh IT\Python\output\write_text.txt

- whenever in this situation we no need to create a folder manually

- we will create

# %%
os.getcwd()+'\output'
# Out:
# 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python\\output'

# %%
folder_name='output'
os.getcwd()+folder_name
os.getcwd()+'\\'+folder_name    # working(average
os.getcwd()+'/'+folder_name     # not better
os.getcwd()+f"\{folder_name}"    # working  (hit)

os.path.join(os.getcwd(),folder_name)   # working (superhit)
# Out:
# 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python\\output'

# %% [markdown]
# **how to create a folder**

# %% [markdown]
# **os.makedirs**
#
# - this is the method to create folder

# %%
current_path=os.getcwd()
folder_name='outputs'
new_dir=os.path.join(current_path,folder_name)
os.makedirs(new_dir)

# %%
current_path=os.getcwd()
folder_name='outputs'
new_dir=os.path.join(current_path,folder_name)
os.makedirs(new_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[11], line 4
#       2 folder_name='outputs'
#       3 new_dir=os.path.join(current_path,folder_name)
# ----> 4 os.makedirs(new_dir)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python\\outputs'

# %%
current_path=os.getcwd()
folder_name='Umesh'
new_dir=os.path.join(current_path,folder_name)
os.makedirs(new_dir)

# %%
try:
    current_path=os.getcwd()
    folder_name='Umesh'
    new_dir=os.path.join(current_path,folder_name)
    os.makedirs(new_dir)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python\\Umesh'

# %%
file_name='Umesh_file.txt'
path=os.path.join(new_dir,file_name)
with open(path,mode='w') as file:
    file.write('hello my name is Umesh')

# %%
with open(path,mode='r') as file:
    data=file.read()
print(data)
# Out:
# hello my name is Umesh

# %%
- step-1 create a folder

- step-2 to create a folder we will use: os.makedir()

- step-3 os.makedir will take the path

    - the path is: full folder path

    - imagine that if you create a folder what is the full path

    - c:user\\................\\foldername

- step-4: Again in this we have two things

    - current working directory

    - folder name

    - we are telling ti python you concatenate both

- step-5: os.path.join will concatenate both current working directory and folder name

# %%
cwd=os.getcwd()
cwd
folder_name='outputs1'
new_dir=os.path.join(cwd,folder_name)
new_dir
os.makedirs(new_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 6
#       4 new_dir=os.path.join(cwd,folder_name)
#       5 new_dir
# ----> 6 os.makedirs(new_dir)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python\\outputs1'

# %%
#'C:\Users\ukush\Documents\Naresh IT\Python\outputs1'
file_name='file1.txt'
os.path.join(new_dir,file_name)
# Out:
# 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python\\outputs1\\file1.txt'

# %%
with open('C:\Users\ukush\Documents\Naresh IT\Python\outputs1file,mode='w') as file:
    file.write('hello i am umesh')

# %%
folder_dir=new_dir
file_name='file.txt'
path=os.path.join(folder_dir,file_name)
with open(path,mode='w') as file:
    file.write('hello i am umesh kushwaha')

# %%
with open(path,mode='r') as file:
    data=file.read()
print(data)
# Out:
# hello i am umesh kushwaha

# %%
import os
cwd=os.getcwd()
cwd
folder_name='Outputs_2'
new_dir=os.path.join(cwd,folder_name)
new_dir
os.makedirs(new_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[8], line 7
#       5 new_dir=os.path.join(cwd,folder_name)
#       6 new_dir
# ----> 7 os.makedirs(new_dir)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\ukush\\Documents\\Naresh IT\\Python\\Outputs_2'

# %%
folder_dir=new_dir
file_name='Umesh_ck.txt'
path=os.path.join(folder_dir,file_name)
with open(path,mode='w') as file:
    file.write('Hello my Name is Umesh Chandra Kushwaha')

# %%
with open(path,mode='r') as file:
    data=file.read()
data
# Out:
# 'Hello my Name is Umesh Chandra Kushwaha'

# %%
with open(path,mode='r') as file:
    data=file.read()
print(data)
# Out:
# Hello my Name is Umesh Chandra Kushwaha

# %% [markdown]
# **Q1 find bthe number of lines in mbox-shot**

# %%
path="mbox-short.txt"
file=open(path,mode='r',encoding='utf-8-sig')
data=file.read()

for i in data.split('\n'):
    print(i)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
path="mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
path="mbox-short.txt"
file=open(path)
count=0
for i in file:
    count+=1

print(count)
# Out:
# 1910

# %%
# task :writ a file
# rule -1 : take a new file name
#       
#  those who are getting more than 2125
# lot of space

# %%
path="mbox-short.txt"
file=open(path)
count=0
for i in file:
    count+=1

print(count+1)
# Out:
# 1911

# %% [markdown]
# **enumerate**

# %%
- it is a inbuilt function like zip
- it will give the values
        - one is index of the line
        - second actual line

# %%
path="mbox-short.txt"
file=open(path)
for i in enumerate(file):
    print(i)
# Out:
# (0, 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n')
# (1, 'Return-Path: <postmaster@collab.sakaiproject.org>\n')
# (2, 'Received: from murder (mail.umich.edu [141.211.14.90])\n')
# (3, '\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n')
# (4, '\t Sat, 05 Jan 2008 09:14:16 -0500\n')
# (5, 'X-Sieve: CMU Sieve 2.3\n')
# (6, 'Received: from murder ([unix socket])\n')
# (7, '\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n')
# (8, '\t Sat, 05 Jan 2008 09:14:16 -0500\n')
# (9, 'Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n')
# (10, '\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n')
# (11, '\tSat, 5 Jan 2008 09:14:15 -0500\n')
# (12, 'Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n')
# (13, '\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n')
# (14, '\t 5 Jan 2008 09:14:10 -0500\n')
# (15, 'Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n')
# ...

# %%
a=10,20
a
# Out:
# (10, 20)

# %%
def fun():
    a=10
    b=20
    return(a,b)

val=fun()
val

# %%
path="mbox-short.txt"
file=open(path)
for ix,line in enumerate(file):
    print(ix,line)
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 11 	Sat, 5 Jan 2008 09:14:15 -0500
#
# 12 Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 13 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 14 	 5 Jan 2008 09:14:10 -0500
#
# 15 Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 16 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 17 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
path="mbox-short.txt"
file=open(path)
for i,j in enumerate(file):
    print(i,j)
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 11 	Sat, 5 Jan 2008 09:14:15 -0500
#
# 12 Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 13 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 14 	 5 Jan 2008 09:14:10 -0500
#
# 15 Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 16 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 17 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
path="mbox-short.txt"
file=open(path)
for ix,line in enumerate(file):
    print(ix,line)
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 11 	Sat, 5 Jan 2008 09:14:15 -0500
#
# 12 Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 13 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 14 	 5 Jan 2008 09:14:10 -0500
#
# 15 Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 16 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 17 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
ix+1
# Out:
# 1910

# %%
- whenever we defines  one variable
- that variable is not using
- without that variable the code will not work
- that variable we can replace with _

# %%
path="mbox-short.txt"
file=open(path)
for ix,_ in enumerate(file):
    pass                            # instead of print we can use 'pass'

ix
# Out:
# 1909

# %%
for i in range(10):
    print(i,end='')
# Out:
# 0123456789

# %%
i
# Out:
# 9

# %%
you can always verify
how the class is progress ===== other trainer

python 40 days

# %%
#Q@ when you read the data some of the data is not alignment

# %%
path="mbox-short.txt"
file=open(path)
for line in file:
    print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# X-Sieve: CMU Sieve 2.3
#
# Received: from murder ([unix socket])
#
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 	Sat, 5 Jan 2008 09:14:15 -0500
#
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 	 5 Jan 2008 09:14:10 -0500
#
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
path="mbox-short.txt"
file=open(path)
for line in file:
    print(line.strip())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# ...

# %% [markdown]
# **Q3 get line which are starting with from and save in a list**

# %%
path="mbox-short.txt"
file=open(path)
for line in file:
    if line.startswith('From'):
        print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# From: stephen.marquard@uct.ac.za
#
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
#
# From: louis@media.berkeley.edu
#
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
#
# From: zqian@umich.edu
#
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
#
# From: rjlowe@iupui.edu
#
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
#
# From: zqian@umich.edu
#
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
#
# From: rjlowe@iupui.edu
#
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
#
# From: cwen@iupui.edu
#
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
#
# From: cwen@iupui.edu
#
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
#
# From: gsilver@umich.edu
#
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
#
# From: gsilver@umich.edu
#
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
#
# From: zqian@umich.edu
#
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
#
# From: gsilver@umich.edu
#
# ...

# %%
path="mbox-short.txt"
file=open(path)
for line in file:
    if line.startswith('From'):
        from_list.append(line)

from_list
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
path="mbox-short.txt"
file=open(path)
from_list=[line for line in file if line.startswith('From')]
from_list
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n',
#  'From: stephen.marquard@uct.ac.za\n',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008\n',
#  'From: louis@media.berkeley.edu\n',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008\n',
#  'From: zqian@umich.edu\n',
# ...

# %%
path="mbox-short.txt"
file=open(path)
from_list=[line for line in file if line.startswith('From')]
len(from_list)
# Out:
# 54

# %%
from_list
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n',
#  'From: stephen.marquard@uct.ac.za\n',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008\n',
#  'From: louis@media.berkeley.edu\n',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008\n',
#  'From: zqian@umich.edu\n',
# ...

# %% [markdown]
# **Q4 in above output we need to remove \n at the end**
#
# - take above output as input
# - iterate is apply rstrip
# - keep in another list

# %%
list1=[]
for line in from_list:
    list1.append(line.rstrip('\n'))

# %%
list1
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
list1=[]
for line in from_list:
    list1.append(line.rstrip('\n'))

list1
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
path="mbox-short.txt"
file=open(path)
from_list=[line.rstrip('\n') for line in file if line.startswith('From')]
(from_list)
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
#Q5 from above outputs  you need to extract all the emails
#Q6 unique emails
#Q7 you need to read the text file
nallagoni, omkar <nallagoni.omkar@accenture.com>
fname=
sname=
emailId=
cname=

# %%
path="mbox-short.txt"
file=open(path)
from_list=[line.rstrip('\n') for line in file if line.startswith('From')]
(from_list)
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...
