# %%
s=0
def add():
    s1=s+10
    print(s1)

add()
# Out:
# 10

# %%
b=0
def add1():
    s=b+10
    print(s)

add1()
# Out:
# 10

# %%
s=0
def add():
    c=s+10
    s=c
    print(s)

add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 7
#       4     s=c
#       5     print(s)
# ----> 7 add()
#
# Cell In[5], line 3, in add()
#       2 def add():
# ----> 3     c=s+10
#       4     s=c
#       5     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
n1=10
def addition():
    n1=100
    n2=200
    n3=n1+n2
    print(n1,n2,n3)

addition()
# Out:
# 100 200 300

# %%
** note**
- if you give same variable as global and local
- make sure that variable should not used as value inside

# %%
n11=10
def addition():
    n22=200+n11
    n33=n11+n22
    print(n11,n22,n33)

addition()

n11=10
define the function
call the function
run the function
        n11 is global variable passing inside the function(yes)
        n22=200+n11   200+10=210
        n33=10+210=220
        print
# Out:
# 10 210 220

# %%
s=0
def add():
    c=s+10
    s=c
    print(s)

add()



-      c is local variable:     c=s+10 = c=10
-      we are creating a new variabble same like global variable   s
- we are creating a new variabble same like global variable
- by using global variable
# Out:
#   Cell In[4], line 11
#     -      c is local variable:     c=s+10 = c=10
#                       ^
# SyntaxError: invalid syntax

# %%
a=100
def greet():
    a=200
    print('hello')

greet()
# Out:
# hello

# %%
a
# Out:
# 100

# %%
value=100
def greet():
    value=200
    print('hello')

greet()
# Out:
# hello

# %%
*global keyword*
- blobal keyword used to take the local variable value outside the function

# %%
value=100
def greet():
    global value
    value=200
    print('hello')

greet()
print('value',value)
# Out:
# hello
# value 200

# %%
n11=10
def addition():
    global n22,n33
    n22=200
    n33=n11+n22
    print(n11,n22,n33)

addition()
print(n22)
print(n33)
# Out:
# 10 200 210
# 200
# 210

# %%
- out side the function is called GV
- inside the function LV
- LV cannot use outside the function
- if you want to use outside the function use global keyword

# %%
def mul(a,b):
    print(a*b)

mul(eval(input()),
    eval(input()))
# Out:
#  30
#  20
# 600

# %%
** Return**
- we can use the LV or function output outside the function using return
- print is different
- return is different
- print is used to only to print the values
- that value you can only see, but you can not use
- if you wanr to use outside we will use return (its also possible by using

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    print(avg)

average()
# Out:
# 20.0

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg)

avg=average()

#   function is ready to return values to me
# so i need to store

# %%
avg
# Out:
# 20.0

# %%
def average():
    global n3,avg
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg,n3)

avg,n3=average()

#   function is ready to return values to me
# so i need to store
# how many value returning
# we will store each value in different variablr
# because two values are diff.
# if you use only variable to store : tuple value
# return always atbthe last line of the function
# not in middle lines

# %%
avg
# Out:
# 20.0

# %%
n3
# Out:
# 30

# %%
def sub():
    a=10
    b=20
    subb=b-a
    return(subb)

subb=sub()

# %%
subb
# Out:
# 10

# %%
def sub():
    a=10
    b=20
    subb=b-a
    return(a,b,subb)

out=sub()

# %%
out
# Out:
# (10, 20, 10)

# %%
def sub():
    a=10
    b=20
    subb=b-a
    return(a,b,subb)

a,b,subb=sub()

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
subb
# Out:
# 10

# %% [markdown]
# - with out argumrnt
# - with
# - default
# - local-global
# - global keyword
# - return
# - function in function
# - kwargs: keyword arguments

# %% [markdown]
# **unbound local error**

# %%
num=10
def fun1():
    num1=100
    print("inside function",num1)

fun1()
# Out:
# 100

# %%
num1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num1
#
# NameError: name 'num1' is not defined

# %%
num2=10
def fun2():
    print(num2)
    num2=100

fun2()

# name error will come
# LV and GV both name are same
# you are trying to access LV before assign
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3     print(num2)
#       4     num2=100
# ----> 6 fun2()
#
# Cell In[4], line 3, in fun2()
#       2 def fun2():
# ----> 3     print(num2)
#       4     num2=100
#
# UnboundLocalError: cannot access local variable 'num2' where it is not associated with a value

# %%
num=10
def fun1():
    num1=100
    print("inside function",num1)

fun1()
print("outside function", num)
# Out:
# inside function 100
# outside function 10

# %%
a1=100
b1=100
def add11():
    add1=a1+b1
    print(add1)

add11()

#
# Out:
# 200

# %%
a1=100
b1=100
def add11():
    add1=a1+b1
    print(add1)

add11()
# Out:
# 200

# %%
a1=100
b1=100
def add12():
    a1=500
    b1=700
    add1=a1+b1
    print(add1)

add12()

we are initial
# Out:
# 1200

# %%
a1=100
b1=200
def add13():
    add1=a1+b1
    a1=500
    b1=700
    print(add1)

add1()

# we are initialising LV names same as GV
# we are using LV before initialising
# Out:
# 10

# %%
- no error
- here no LV as same as GV

- we are initialising LV name as GV
- we are using LV after initialzation

- error
- we are initilsing LV same as GV
- we are using LV before initialztion

# %%
b21=200
def add21():
    a21=1000
    add1=a21+b21
    b21=2000
    print(add1)

add21()
a1=6000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       3     add1=a21+b21
#       4     print(add21)
# ----> 6 add21()
#       7 a1=6000
#
# Cell In[14], line 3, in add21()
#       2 def add21():
# ----> 3     add1=a21+b21
#       4     print(add21)
#
# NameError: name 'a21' is not defined

# %%
b21=200
def add21():
    a21=1000
    add1=a21+b21
    b21=2000
    print(add1)

add21()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[19], line 8
#       5     b21=2000
#       6     print(add1)
# ----> 8 add21()
#
# Cell In[19], line 4, in add21()
#       2 def add21():
#       3     a21=1000
# ----> 4     add1=a21+b21
#       5     b21=2000
#       6     print(add1)
#
# UnboundLocalError: cannot access local variable 'b21' where it is not associated with a value

# %%
- GV 
- define
- call
- run

# %% [markdown]
# **functions in functions**

# %%
def greet1():
    print('hello good morning')

def greet2():
    print('good night!')

greet1()
greet2()
# Out:
# hello good morning
# good night!

# %%
def greet2():
    print('good night!')
    
def greet1():
    print('hello good morning')
    greet2()

greet1()
# Out:
# hello good morning
# good night!

# %%
def greet2():
    print('good night!')
    greet1()
    
def greet1():
    print('hello good morning')
    greet2()

greet1()
# Out:
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# hello good morning
# good night!
# ...

# %% [markdown]
# - functions without arguments
# - function with argument
# - function default arguments
# - GV vs LV
# - global keyword
# - return statement
# - unbound local error
# - function in functions

# %%
distance=eval(input("enter the distance"))
cutoff_distance=eval(input("enter the cutoff distance"))
if distance>cutoff_distance:
    chargeable_distance=distance-cutoff_distance
    print(f"the chargeable distance is {chargeable_distance}")
    charge=eval(input("enter the charge"))
    cost=chargeable_distance*charge
    print(f"the total charge is {cost}")

else:
    print(f"it's a free ride enjoy")
# Out:
# enter the distance 26
# enter the cutoff distance 12
# the chargeable distance is 14
# enter the charge 30
# the total charge is 420

# %%
def total_fare():
    distance=eval(input("enter the distance"))
    cutoff_distance=eval(input("enter the cutoff distance"))
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        charge=eval(input("enter the charge"))
        cost=chargeable_distance*charge
        print(f"the total charge is {cost}")

    else:
        print(f"It's a free ride enjoy")


total_fare()
# Out:
# enter the distance 50
# enter the cutoff distance 25
# the chargeable distance is 25
# enter the charge 32
# the total charge is 800

# %%
def total_fare2(distance,cutoff_distance,charge):
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        cost=chargeable_distance*charge
        print(f"the total charge is {cost}")

    else:
        print(f"It's a free ride enjoy")

total_fare2(55,20,25)
# Out:
# the chargeable distance is 35
# the total charge is 875

# %%
def total_fare3(distance,cutoff_distance=20,charge=25):
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        cost=chargeable_distance*charge
        print(f"the total charge is {cost}")

    else:
        print(f"It's a free ride enjoy")

total_fare3(55)
# Out:
# the chargeable distance is 35
# the total charge is 875

# %%
distance=eval(input("enter the distance"))
cutoff_distance=eval(input("enter the cutoff distance"))
def total_fare4():
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        charge=eval(input("enter the charge"))
        cost=chargeable_distance*charge
        print(f"the total charge is", cost)

    else:
        print(f"It's a free ride enjoy")

total_fare4()
# Out:
# enter the distance 55
# enter the cutoff distance 20
# the chargeable distance is 35
# enter the charge 25
# the total charge is 875

# %%
distance=eval(input("enter the distance"))
cutoff_distance=eval(input("enter the cutoff distance"))
def total_fare5():
    global cost
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        charge=eval(input("enter the charge"))
        cost=chargeable_distance*charge
        print(f"the total charge is", cost)

    else:
        print(f"It's a free ride enjoy")

total_fare5()
print("outside function cost",cost)
# Out:
# enter the distance 55
# enter the cutoff distance 20
# the chargeable distance is 35
# enter the charge 25
# the total charge is 875
# outside function cost 875

# %%
cost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 cost
#
# NameError: name 'cost' is not defined

# %%
distance=eval(input("enter the distance"))
cutoff_distance=eval(input("enter the cutoff distance"))
def total_fare6():
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        charge=eval(input("enter the charge"))
        cost=chargeable_distance*charge
        print(f"the total charge is", cost)
        return(cost)

    else:
        cost=100

total_fare6()
# Out:
# enter the distance 60
# enter the cutoff distance 25
# the chargeable distance is 35
# enter the charge 20
# the total charge is 700
# 700

# %%
distance=eval(input("enter the distance"))
cutoff_distance=eval(input("enter the cutoff distance"))
def total_fare7():
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        charge=eval(input("enter the charge"))
        cost=chargeable_distance*charge
        print(f"the total charge is", cost)
        return(cost)

    else:
        cost=100
        return(cost)

total_fare7()
print("outside function cost",cost)
# Out:
# enter the distance 30
# enter the cutoff distance 20
# the chargeable distance is 10
# enter the charge 20
# the total charge is 200
# outside function cost None

# %%
distance=eval(input("enter the distance"))
cutoff_distance=eval(input("enter the cutoff distance"))
def total_fare8():
    if distance>cutoff_distance:
        chargeable_distance=distance-cutoff_distance
        print(f"the chargeable distance is {chargeable_distance}")
        charge=eval(input("enter the charge"))
        cost=chargeable_distance*charge
        print(f"the total charge is", cost)

    else:
        cost=100
        return(cost)

cost=total_fare8()
print("outside function cost",cost)
# Out:
# enter the distance 60
# enter the cutoff distance 15
# the chargeable distance is 45
# enter the charge 20
# the total charge is 900
# outside function cost None

# %%
# first create 4 individual function
# fun1: add
# fun2: sub
# fun:3: mul
# fun4: div

def add(a,b):
    print(a+b)

# create a main function name: calculator
# inside main function
# print some statements
# option1: addition
# option2: sub, op:mul op:div
# option=eval(input('1-4'))
# a value
# b value
# if option==1:
#       add function
# elif option==2:
#      sub function
# elif option==3:
#      mul function
# elif option==4:
#       div function

# %%
def add(a,b):
    print(a+b)

def sub(a,b):
    print(a-b)

def mul(a,b):
    print(a*b)

def div(a,b):
    print(a/b)

def calculator():
    print("option1,add")
    print("option2,sub")
    print("option3,mul")
    print("option3,div")
    option=eval(input("1 to 4="))
    a=eval(input("enter the number"))
    b=eval(input("enter the number"))
    if option==1:
        print(add)
    elif option==2:
        print(sub)
    elif option==3:
        print(mul)
    elif option==4:
        print(div)
    else:
        print(nothing)

calculator()
# Out:
# option1,add
# option2,sub
# option3,mul
# option3,div
# 1 to 4= 2
# enter the number 3
# enter the number 3
# <function sub at 0x0000024A4808E340>

# %%
def add(a,b):
    print(a+b)

def sub(a,b):
    print(a-b)

def mul(a,b):
    print(a*b)

def div(a,b):
    print(a/b)

def calculator():
    print("option1,add")
    print("option2,sub")
    print("option3,mul")
    print("option3,div")
    option=eval(input("1 to 4="))
    a=10
    b=20
    if option==1:
        add(a,b)
    elif option==2:
        sub(a,b)
    elif option==3:
        mul(a,b)
    elif option==4:
        div(a,b)
    else:
        print(nothing)

calculator()
# Out:
# option1,add
# option2,sub
# option3,mul
# option3,div
# 1 to 4= 2
# -10
